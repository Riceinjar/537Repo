# %% [markdown]
# # HW 1: Introduction and Setup
# * Strongly consider completing the tutorial here (unless you already have significant experience with VS Code and Python) - https://code.visualstudio.com/docs/python/python-tutorial
# * Create a virtual environment and install this project from the repository root with `python -m pip install -e .` (see `pyproject.toml` and https://code.visualstudio.com/docs/python/environments#_creating-environments).
# * Run this notebook and check the output
# * If things are set up correctly, you should see two coordinate frames appear in a new window.
# * Play with these values a little to start to get some intuition for what these matrices mean.

# %%
# this cell will fail if the installed byu_robomanip package is unavailable
import numpy as np
import time
from byu_robomanip.visualization import VizScene

Tw_to_frame1 = np.eye(4)

viz = VizScene()
viz.add_frame(np.eye(4), label='world', axes_label='w')
viz.add_frame(Tw_to_frame1, label='frame1', axes_label='1')

time_to_run = 10
refresh_rate = 60
t = 0
start = time.time()
while t < time_to_run:
    t = time.time() - start

    # you can play with omega and p to see how they affect the frame
    omega = np.pi/2
    R = np.array([[np.cos(omega*t), -np.sin(omega*t), 0],
                  [np.sin(omega*t), np.cos(omega*t), 0],
                  [0, 0, 1]])
    p = np.array([1, 0, 0])

    Tw_to_frame1[:3,:3] = R
    Tw_to_frame1[:3,-1] = p
    viz.update(As=[np.eye(4), Tw_to_frame1])

    viz.hold(1/refresh_rate)

viz.close_viz() # could use viz.hold() to keep it open until manually closed
# Out:
# c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py:256: RuntimeWarning:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 203, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\traitlets\config\application.py", line 1080, in launch_instance
#     app.start()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelapp.py", line 807, in start
#     self.io_loop.start()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Novo\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\base_events.py", line 678, in run_forever
#     self._run_once()
#   File "C:\Users\Novo\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\base_events.py", line 2057, in _run_once
#     handle._run()
#   File "C:\Users\Novo\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\events.py", line 94, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 460, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\zmqshell.py", line 665, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3248, in run_cell
#     result = self._run_cell(
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3305, in _run_cell
#     result = runner(coro)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\async_helpers.py", line 140, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3518, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3762, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3823, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Novo\AppData\Local\Temp\ipykernel_18664\137566295.py", line 8, in <module>
#     viz = VizScene()
#   File "C:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\src\byu_robomanip\visualization.py", line 248, in __init__
#     self.window.show()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 217, in paintGL
#     self.paint(region=region, viewport=region)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 229, in paint
#     self.drawItemTree(useItemNames=useItemNames)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 261, in drawItemTree
#     self.drawItemTree(i, useItemNames=useItemNames)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 261, in drawItemTree
#     self.drawItemTree(i, useItemNames=useItemNames)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 256, in drawItemTree
#     debug.printExc()
#   --- exception caught here ---
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 253, in drawItemTree
#     i.paint()
#     ~~~~~~~^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\items\GLLinePlotItem.py", line 202, in paint
#     with program:
#          ^^^^^^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\OpenGL\GL\shaders.py", line 94, in __enter__
#     glUseProgram( self )
#     ~~~~~~~~~~~~^^^^^^^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\OpenGL\latebind.py", line 43, in __call__
#     return self._finalCall( *args, **named )
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\OpenGL\error.py", line 230, in glCheckError
#     raise self._errorClass(
#     ...<4 lines>...
#     )
# OpenGL.error.GLError: GLError(
# 	err = 1281,
# 	description = b'invalid value',
# 	baseOperation = glUseProgram,
# 	cArguments = (3,)
# )
#   debug.printExc()
# c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py:256: RuntimeWarning:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 203, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\traitlets\config\application.py", line 1080, in launch_instance
#     app.start()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelapp.py", line 807, in start
#     self.io_loop.start()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Novo\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\base_events.py", line 678, in run_forever
#     self._run_once()
#   File "C:\Users\Novo\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\base_events.py", line 2057, in _run_once
#     handle._run()
#   File "C:\Users\Novo\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\events.py", line 94, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 460, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\zmqshell.py", line 665, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3248, in run_cell
#     result = self._run_cell(
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3305, in _run_cell
#     result = runner(coro)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\async_helpers.py", line 140, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3518, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3762, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3823, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Novo\AppData\Local\Temp\ipykernel_18664\137566295.py", line 8, in <module>
#     viz = VizScene()
#   File "C:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\src\byu_robomanip\visualization.py", line 252, in __init__
#     self.app.processEvents()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 217, in paintGL
#     self.paint(region=region, viewport=region)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 229, in paint
#     self.drawItemTree(useItemNames=useItemNames)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 261, in drawItemTree
#     self.drawItemTree(i, useItemNames=useItemNames)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 261, in drawItemTree
#     self.drawItemTree(i, useItemNames=useItemNames)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 256, in drawItemTree
#     debug.printExc()
#   --- exception caught here ---
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 253, in drawItemTree
#     i.paint()
#     ~~~~~~~^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\items\GLLinePlotItem.py", line 202, in paint
#     with program:
#          ^^^^^^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\OpenGL\GL\shaders.py", line 94, in __enter__
#     glUseProgram( self )
#     ~~~~~~~~~~~~^^^^^^^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\OpenGL\latebind.py", line 43, in __call__
#     return self._finalCall( *args, **named )
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\OpenGL\error.py", line 230, in glCheckError
#     raise self._errorClass(
#     ...<4 lines>...
#     )
# OpenGL.error.GLError: GLError(
# 	err = 1281,
# 	description = b'invalid value',
# 	baseOperation = glUseProgram,
# 	cArguments = (3,)
# )
#   debug.printExc()
# c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py:256: RuntimeWarning:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 203, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\traitlets\config\application.py", line 1080, in launch_instance
#     app.start()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelapp.py", line 807, in start
#     self.io_loop.start()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Novo\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\base_events.py", line 678, in run_forever
#     self._run_once()
#   File "C:\Users\Novo\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\base_events.py", line 2057, in _run_once
#     handle._run()
#   File "C:\Users\Novo\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\events.py", line 94, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 460, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\zmqshell.py", line 665, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3248, in run_cell
#     result = self._run_cell(
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3305, in _run_cell
#     result = runner(coro)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\async_helpers.py", line 140, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3518, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3762, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3823, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Novo\AppData\Local\Temp\ipykernel_18664\137566295.py", line 9, in <module>
#     viz.add_frame(np.eye(4), label='world', axes_label='w')
#   File "C:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\src\byu_robomanip\visualization.py", line 383, in add_frame
#     self.app.processEvents()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 217, in paintGL
#     self.paint(region=region, viewport=region)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 229, in paint
#     self.drawItemTree(useItemNames=useItemNames)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 261, in drawItemTree
#     self.drawItemTree(i, useItemNames=useItemNames)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 261, in drawItemTree
#     self.drawItemTree(i, useItemNames=useItemNames)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 256, in drawItemTree
#     debug.printExc()
#   --- exception caught here ---
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 253, in drawItemTree
#     i.paint()
#     ~~~~~~~^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\items\GLLinePlotItem.py", line 202, in paint
#     with program:
#          ^^^^^^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\OpenGL\GL\shaders.py", line 94, in __enter__
#     glUseProgram( self )
#     ~~~~~~~~~~~~^^^^^^^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\OpenGL\latebind.py", line 43, in __call__
#     return self._finalCall( *args, **named )
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\OpenGL\error.py", line 230, in glCheckError
#     raise self._errorClass(
#     ...<4 lines>...
#     )
# OpenGL.error.GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glUseProgram,
# 	cArguments = (3,)
# )
#   debug.printExc()
# c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py:256: RuntimeWarning:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 203, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\traitlets\config\application.py", line 1080, in launch_instance
#     app.start()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelapp.py", line 807, in start
#     self.io_loop.start()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Novo\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\base_events.py", line 678, in run_forever
#     self._run_once()
#   File "C:\Users\Novo\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\base_events.py", line 2057, in _run_once
#     handle._run()
#   File "C:\Users\Novo\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\events.py", line 94, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 460, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\zmqshell.py", line 665, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3248, in run_cell
#     result = self._run_cell(
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3305, in _run_cell
#     result = runner(coro)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\async_helpers.py", line 140, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3518, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3762, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3823, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Novo\AppData\Local\Temp\ipykernel_18664\137566295.py", line 9, in <module>
#     viz.add_frame(np.eye(4), label='world', axes_label='w')
#   File "C:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\src\byu_robomanip\visualization.py", line 383, in add_frame
#     self.app.processEvents()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 217, in paintGL
#     self.paint(region=region, viewport=region)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 229, in paint
#     self.drawItemTree(useItemNames=useItemNames)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 261, in drawItemTree
#     self.drawItemTree(i, useItemNames=useItemNames)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 256, in drawItemTree
#     debug.printExc()
#   --- exception caught here ---
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 253, in drawItemTree
#     i.paint()
#     ~~~~~~~^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\items\GLMeshItem.py", line 253, in paint
#     if (loc := GL.glGetAttribLocation(program, "a_position")) != -1:
#                ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\OpenGL\latebind.py", line 63, in __call__
#     return self.wrapperFunction( self.baseFunction, *args, **named )
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\OpenGL\GL\VERSION\GL_2_0.py", line 480, in glGetAttribLocation
#     return baseOperation(program, name)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\OpenGL\error.py", line 230, in glCheckError
#     raise self._errorClass(
#     ...<4 lines>...
#     )
# OpenGL.error.GLError: GLError(
# 	err = 1281,
# 	description = b'invalid value',
# 	baseOperation = glGetAttribLocation,
# 	cArguments = (11, b'a_position\x00'),
# 	result = -1
# )
#   debug.printExc()
# c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py:256: RuntimeWarning:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 203, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\traitlets\config\application.py", line 1080, in launch_instance
#     app.start()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelapp.py", line 807, in start
#     self.io_loop.start()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Novo\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\base_events.py", line 678, in run_forever
#     self._run_once()
#   File "C:\Users\Novo\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\base_events.py", line 2057, in _run_once
#     handle._run()
#   File "C:\Users\Novo\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\events.py", line 94, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 460, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\zmqshell.py", line 665, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3248, in run_cell
#     result = self._run_cell(
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3305, in _run_cell
#     result = runner(coro)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\async_helpers.py", line 140, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3518, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3762, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3823, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Novo\AppData\Local\Temp\ipykernel_18664\137566295.py", line 10, in <module>
#     viz.add_frame(Tw_to_frame1, label='frame1', axes_label='1')
#   File "C:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\src\byu_robomanip\visualization.py", line 383, in add_frame
#     self.app.processEvents()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 217, in paintGL
#     self.paint(region=region, viewport=region)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 229, in paint
#     self.drawItemTree(useItemNames=useItemNames)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 261, in drawItemTree
#     self.drawItemTree(i, useItemNames=useItemNames)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 261, in drawItemTree
#     self.drawItemTree(i, useItemNames=useItemNames)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 256, in drawItemTree
#     debug.printExc()
#   --- exception caught here ---
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 253, in drawItemTree
#     i.paint()
#     ~~~~~~~^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\items\GLLinePlotItem.py", line 202, in paint
#     with program:
#          ^^^^^^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\OpenGL\GL\shaders.py", line 94, in __enter__
#     glUseProgram( self )
#     ~~~~~~~~~~~~^^^^^^^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\OpenGL\latebind.py", line 43, in __call__
#     return self._finalCall( *args, **named )
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\OpenGL\error.py", line 230, in glCheckError
#     raise self._errorClass(
#     ...<4 lines>...
#     )
# OpenGL.error.GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glUseProgram,
# 	cArguments = (3,)
# )
#   debug.printExc()
# c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py:256: RuntimeWarning:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 203, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\traitlets\config\application.py", line 1080, in launch_instance
#     app.start()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelapp.py", line 807, in start
#     self.io_loop.start()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Novo\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\base_events.py", line 678, in run_forever
#     self._run_once()
#   File "C:\Users\Novo\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\base_events.py", line 2057, in _run_once
#     handle._run()
#   File "C:\Users\Novo\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\events.py", line 94, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 460, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\ipykernel\zmqshell.py", line 665, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3248, in run_cell
#     result = self._run_cell(
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3305, in _run_cell
#     result = runner(coro)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\async_helpers.py", line 140, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3518, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3762, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3823, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Novo\AppData\Local\Temp\ipykernel_18664\137566295.py", line 10, in <module>
#     viz.add_frame(Tw_to_frame1, label='frame1', axes_label='1')
#   File "C:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\src\byu_robomanip\visualization.py", line 383, in add_frame
#     self.app.processEvents()
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 217, in paintGL
#     self.paint(region=region, viewport=region)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 229, in paint
#     self.drawItemTree(useItemNames=useItemNames)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 261, in drawItemTree
#     self.drawItemTree(i, useItemNames=useItemNames)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 256, in drawItemTree
#     debug.printExc()
#   --- exception caught here ---
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\GLViewWidget.py", line 253, in drawItemTree
#     i.paint()
#     ~~~~~~~^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\pyqtgraph\opengl\items\GLMeshItem.py", line 253, in paint
#     if (loc := GL.glGetAttribLocation(program, "a_position")) != -1:
#                ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\OpenGL\latebind.py", line 63, in __call__
#     return self.wrapperFunction( self.baseFunction, *args, **named )
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\OpenGL\GL\VERSION\GL_2_0.py", line 480, in glGetAttribLocation
#     return baseOperation(program, name)
#   File "c:\Users\Novo\Documents\IMPORTANT\BYU\ME EN 537 - Robotics\537Repo\.venv\Lib\site-packages\OpenGL\error.py", line 230, in glCheckError
#     raise self._errorClass(
#     ...<4 lines>...
#     )
# OpenGL.error.GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glGetAttribLocation,
# 	cArguments = (11, b'a_position\x00'),
# 	result = -1
# )
#   debug.printExc()
# Error while drawing item <pyqtgraph.opengl.items.GLLinePlotItem.GLLinePlotItem(0x2370bc44980) at 0x00000237140CC1C0>.
# Error while drawing item <pyqtgraph.opengl.items.GLLinePlotItem.GLLinePlotItem(0x2370bc44980) at 0x00000237140CC1C0>.
# Error while drawing item <pyqtgraph.opengl.items.GLLinePlotItem.GLLinePlotItem(0x2370bc44980) at 0x00000237140CC1C0>.
# Error while drawing item <pyqtgraph.opengl.items.GLMeshItem.GLMeshItem(0x2370bc44340) at 0x00000237140AFCC0>.
# Error while drawing item <pyqtgraph.opengl.items.GLMeshItem.GLMeshItem(0x2370bc449d0) at 0x000002370D8618C0>.
# Error while drawing item <pyqtgraph.opengl.items.GLMeshItem.GLMeshItem(0x2370bc44520) at 0x0000023716C26500>.
# Error while drawing item <pyqtgraph.opengl.items.GLLinePlotItem.GLLinePlotItem(0x2370bc44980) at 0x00000237140CC1C0>.
# Error while drawing item <pyqtgraph.opengl.items.GLMeshItem.GLMeshItem(0x2370bc44340) at 0x00000237140AFCC0>.
# Error while drawing item <pyqtgraph.opengl.items.GLMeshItem.GLMeshItem(0x2370bc449d0) at 0x000002370D8618C0>.
# Error while drawing item <pyqtgraph.opengl.items.GLMeshItem.GLMeshItem(0x2370bc44520) at 0x0000023716C26500>.
# Error while drawing item <pyqtgraph.opengl.items.GLMeshItem.GLMeshItem(0x2370bc40b00) at 0x000002370D79EF00>.
# Error while drawing item <pyqtgraph.opengl.items.GLMeshItem.GLMeshItem(0x2370bc40bf0) at 0x0000023716CB8BC0>.
# Error while drawing item <pyqtgraph.opengl.items.GLMeshItem.GLMeshItem(0x2370bc40a10) at 0x0000023716CB99C0>.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 26
#      22                   [np.sin(omega*t), np.cos(omega*t), 0],
#      23                   [0, 0, 1]])
#      24     p = np.array([1, 0, 0])
#      25
# ---> 26     Tw_to_frame1[:3,:2] = R
#      27     Tw_to_frame1[:3,-1] = p
#      28     viz.update(As=[np.eye(4), Tw_to_frame1])
#      29
#
# ValueError: could not broadcast input array from shape (3,3) into shape (3,2)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
